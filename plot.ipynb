# %%
# import pandas with shortcut 'pd'
import pandas as pd  
from matplotlib import pyplot as plt

# Set the figure size
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True

# Make a list of columns
columns = ['i']

# read_csv function which is used to read the required CSV file
data = pd.read_csv('samples.csv')
#   iii,avr,avl,avf,v1,v2,v3,v4,v5,v6,vx,,vz
# display 
print("Original 'input.csv' CSV Data: \n")
print(data)
  
# drop function which is used in removing or deleting rows or columns from the CSV files
data.drop('ii', inplace=True, axis=1)
data.drop('iii', inplace=True, axis=1)
data.drop('avr', inplace=True, axis=1)
data.drop('avl', inplace=True, axis=1)
data.drop('avf', inplace=True, axis=1)
data.drop('v1', inplace=True, axis=1)
data.drop('v2', inplace=True, axis=1)
data.drop('v3', inplace=True, axis=1)
data.drop('v4', inplace=True, axis=1)
data.drop('v5', inplace=True, axis=1)
data.drop('v6', inplace=True, axis=1)
data.drop('vx', inplace=True, axis=1)
data.drop('vy', inplace=True, axis=1)
data.drop('vz', inplace=True, axis=1)
  
# display 
print("\nCSV Data after deleting the column 'year':\n")
print(data)

# Plot the lines
data.plot()
plt.show()
# Out:
# Original 'input.csv' CSV Data:
#
#      'Elapsed time'    'i'     ii    iii    avr    avl    avf     v1     v2  \
# 0        '0:00.000' -0.244 -0.229  0.015  0.237 -0.130 -0.107 -0.044 -0.120
# 1        '0:00.001' -0.242 -0.234  0.009  0.238 -0.126 -0.113 -0.042 -0.117
# 2        '0:00.002' -0.241 -0.234  0.007  0.238 -0.124 -0.114 -0.044 -0.118
# 3        '0:00.003' -0.241 -0.229  0.012  0.235 -0.126 -0.109 -0.045 -0.117
# 4        '0:00.004' -0.232 -0.227  0.004  0.230 -0.118 -0.112 -0.045 -0.117
# ...             ...    ...    ...    ...    ...    ...    ...    ...    ...
# 9995     '0:09.995' -0.003  0.038  0.042 -0.018 -0.021  0.040 -0.036 -0.081
# 9996     '0:09.996'  0.034  0.045  0.011 -0.040  0.011  0.028 -0.053 -0.090
# 9997     '0:09.997'  0.059  0.046 -0.013 -0.053  0.036  0.017 -0.061 -0.095
# 9998     '0:09.998'  0.043  0.045  0.002 -0.044  0.021  0.023 -0.062 -0.090
# 9999     '0:09.999'  0.043  0.046  0.003 -0.044  0.020  0.025 -0.070 -0.090
#
# ...

# %%
import csv
import matplotlib.pyplot as plt

arr = []
with open("samples.csv", "r") as f:
    contents = csv.reader(f)
    flag = 0
    for c in contents:
        if(flag ==0):
            flag = 1
            continue
        # print(type(c[1]))
        arr.append(float(c[1]))
        
# arr.pop(0)
squaredArray = []
for i in range(0,len(arr)):
    squaredArray.append(float(arr[i])*float(arr[i]))
# print(squaredArray)
plt.xlabel('microseconds')
plt.ylabel('mV')

# f = plt.figure()
# f.set_figwidth(4)
# f.set_figheight(1)

plt.figure(figsize=(30, 10))

display(plt.plot(squaredArray))
